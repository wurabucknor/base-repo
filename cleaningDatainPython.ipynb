# %% [markdown]
# <a href="https://colab.research.google.com/github/wurabucknor/base-repo/blob/master/cleaningDatainPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('criketdatamatch.csv')
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4   H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df = df.rename(columns = {'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_score','BF':'Balls_Faced','SR':'Battling_Stike'})
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1     AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    RG Pollock (SA)  1963-1970       23    41         4  2256
# 3    GA Headley (WI)  1930-1954       22    40         4  2190
# 4  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50  0    4s  6s
# 0                334  99.94       9800+           58.60   29  13  7  626+   6
# 1               269*  61.87        2667           55.68    5   4  2   186   5
# 2                274  60.97       1707+           54.48    7  11  1  246+  11
# 3               270*  60.83        416+           56.00   10   5  2  104+   1
# 4                194  60.73       6558+           34.59   16  23  2  202+   6

# %%
df.isnull().any()
# Out:
# Player                False
# Span                  False
# Matches               False
# Inns                  False
# Not_Outs              False
# Runs                  False
# Highest_Inns_score    False
# Ave                   False
# Balls_Faced            True
# Battling_Stike        False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %% [markdown]
# **Show me the roles where there is null values in Balls_face**

# %%
df[df['Balls_Faced'].isnull()]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 17       CL Walcott (WI)  1948-1960       44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50  0    4s  6s
# 8                 207  58.61         NaN             0.0   15  19  6  258+   2
# 17                220  56.68         NaN             0.0   15  14  1  107+  11
# 58               144*  48.79         NaN             0.0    5   6  3   51+   0

# %% [markdown]
# **Fill the null calues with zero**

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %% [markdown]
# Check if null still exit in one of the roles

# %%
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50  0    4s  6s
# 17                220  56.68           0             0.0   15  14  1  107+  11

# %% [markdown]
# Drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().value_counts()
# Out:
# False    63
# True      4
# Name: count, dtype: int64

# %%
#drop duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs   Runs  \
# 11     GS Sobers (WI)  1954-1974       93   160        21   8032
# 23      CA Davis (WI)  1968-1973       15    29         5   1301
# 26  GS Chappell (AUS)  1970-1984       87   151        19   7110
# 42      JE Root (ENG)  2012-2024      149   272        22  12754
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50   0    4s  \
# 11               365*  57.78       4063+           53.58   26  30  12  593+
# 23                183  54.20        665+           35.48    4   4   1   65+
# 26               247*  53.86      13079+           51.53   24  31  12   755
# 42                262  51.01       22306           57.17   35  64  12  1364
#
#      6s
# 11  32+
# 23    1
# 26   16
# 42   44

# %%
#tO CHECK ALL THE DUPLICATES USING THE VALUES

# %%
df[df['Player'].isin(['GS Sobers (WI)','CA Davis(WI)','GS Chappell (AUS)','JE Root (ENG)	'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10     GS Sobers (WI)  1954-1974       93   160        21  8032
# 11     GS Sobers (WI)  1954-1974       93   160        21  8032
# 25  GS Chappell (AUS)  1970-1984       87   151        19  7110
# 26  GS Chappell (AUS)  1970-1984       87   151        19  7110
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50   0    4s  \
# 10               365*  57.78       4063+           53.58   26  30  12  593+
# 11               365*  57.78       4063+           53.58   26  30  12  593+
# 25               247*  53.86      13079+           51.53   24  31  12   755
# 26               247*  53.86      13079+           51.53   24  31  12   755
#
#      6s
# 10  32+
# 11  32+
# 25   16
# 26   16

# %%
df = df.drop_duplicates()
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 2     RG Pollock (SA)  1963-1970       23    41         4  2256
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 4   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# ..                ...        ...      ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981       74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50   0    4s  \
# 0                 334  99.94       9800+           58.60   29  13   7  626+
# ...

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2015-2016
# 2     1963-1970
# 3     1930-1954
# 4     1924-1935
#         ...
# 62    1965-1981
# 63    2002-2014
# 64    1924-1934
# 65    1930-1938
# 66    1928-1934
# Name: Span, Length: 63, dtype: object

# %%
df.dtypes
# Out:
# Player                 object
# Span                   object
# Matches                 int64
# Inns                    int64
# Not_Outs                int64
# Runs                    int64
# Highest_Inns_score     object
# Ave                   float64
# Balls_Faced            object
# Battling_Stike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# dtype: object

# %%
#SPLIT UP Span into start and end date
df['Span']
# Out:
# 0     1928-1948
# 1     2015-2016
# 2     1963-1970
# 3     1930-1954
# 4     1924-1935
#         ...
# 62    1965-1981
# 63    2002-2014
# 64    1924-1934
# 65    1930-1938
# 66    1928-1934
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 62    [1965, 1981]
# 63    [2002, 2014]
# 64    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
#create new column rookie year and store thr first data of the span column
df['Rookie_year'] = df['Span']. str.split(pat = '-').str[0]

# %%
#create a new coliumn final year and store the second data of the span column
df['Final_year'] = df['Span']. str.split(pat = '-').str[1]
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 2     RG Pollock (SA)  1963-1970       23    41         4  2256
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 4   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# ..                ...        ...      ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981       74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_score    Ave Balls_Faced  Battling_Stike  100  50   0    4s  \
# 0                 334  99.94       9800+           58.60   29  13   7  626+
# ...

# %%
#drop the Span column since we donot need it again
df = df.drop(columns = ['Span'], axis = 1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 2    RG Pollock (SA)       23    41         4  2256                274  60.97
# 3    GA Headley (WI)       22    40         4  2190               270*  60.83
# 4  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Battling_Stike  100  50  0    4s  6s Rookie_year Final_year
# 0       9800+           58.60   29  13  7  626+   6        1928       1948
# 1        2667           55.68    5   4  2   186   5        2015       2016
# 2       1707+           54.48    7  11  1  246+  11        1963       1970
# 3        416+           56.00   10   5  2  104+   1        1930       1954
# 4       6558+           34.59   16  23  2  202+   6        1924       1935

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 62     [KD Walters , AUS)]
# 63    [GC Smith , ICC/SA)]
# 64    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
#Create a new column and split the first data
df['Players_name'] = df['Player'].str.split(pat = '(').str[0]
df['Players_name']
# Out:
# 0      DG Bradman
# 1        AC Voges
# 2      RG Pollock
# 3      GA Headley
# 4     H Sutcliffe
#           ...
# 62     KD Walters
# 63       GC Smith
# 64    WH Ponsford
# 65      SJ McCabe
# 66     DR Jardine
# Name: Players_name, Length: 63, dtype: object

# %%
#Create a new column and split the first data
df['Players_country'] = df['Player'].str.split(pat = '(').str[1]
df['Players_country']
# Out:
# 0        AUS)
# 1        AUS)
# 2         SA)
# 3         WI)
# 4        ENG)
#        ...
# 62       AUS)
# 63    ICC/SA)
# 64       AUS)
# 65       AUS)
# 66       ENG)
# Name: Players_country, Length: 63, dtype: object

# %%
df['Players_country'] = df['Players_country'].str.split(pat = ')').str[0]
df['Players_country']
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 4        ENG
#        ...
# 62       AUS
# 63    ICC/SA
# 64       AUS
# 65       AUS
# 66       ENG
# Name: Players_country, Length: 63, dtype: object

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 2    RG Pollock (SA)       23    41         4  2256                274  60.97
# 3    GA Headley (WI)       22    40         4  2190               270*  60.83
# 4  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Battling_Stike  100  50  0    4s  6s Rookie_year Final_year  \
# 0       9800+           58.60   29  13  7  626+   6        1928       1948
# 1        2667           55.68    5   4  2   186   5        2015       2016
# 2       1707+           54.48    7  11  1  246+  11        1963       1970
# 3        416+           56.00   10   5  2  104+   1        1930       1954
# 4       6558+           34.59   16  23  2  202+   6        1924       1935
#
#    Players_name Players_country
# ...

# %%
df.drop(columns = ['Player'])
# Out:
#     Matches  Inns  Not_Outs  Runs Highest_Inns_score    Ave Balls_Faced  \
# 0        52    80        10  6996                334  99.94       9800+
# 1        20    31         7  1485               269*  61.87        2667
# 2        23    41         4  2256                274  60.97       1707+
# 3        22    40         4  2190               270*  60.83        416+
# 4        54    84         9  4555                194  60.73       6558+
# ..      ...   ...       ...   ...                ...    ...         ...
# 62       74   125        14  5357                250  48.26       8662+
# 63      117   205        13  9265                277  48.25       15525
# 64       29    48         4  2122                266  48.22       3118+
# 65       39    62         5  2748                232  48.21       3217+
# 66       22    33         6  1296                127  48.00       2110+
#
#     Battling_Stike  100  50   0    4s  6s Rookie_year Final_year  \
# ...

# %%
df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_Outs                int64
# Runs                    int64
# Highest_Inns_score     object
# Ave                   float64
# Balls_Faced            object
# Battling_Stike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year            object
# Final_year             object
# Players_name           object
# Players_country        object
# dtype: object

# %%
df['Highest_Inns_score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_Inns_score, Length: 63, dtype: object

# %%
df['Highest_Inns_score'] = df['Highest_Inns_score'].str.split(pat = '*').str[0]
df['Highest_Inns_score']
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_Inns_score, Length: 63, dtype: object

# %%
#change the Highest_Inns_Score data types
df['Highest_Inns_score'] = df['Highest_Inns_score'].astype('int')
df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_Outs                int64
# Runs                    int64
# Highest_Inns_score      int64
# Ave                   float64
# Balls_Faced            object
# Battling_Stike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year            object
# Final_year             object
# Players_name           object
# Players_country        object
# dtype: object

# %%
df = df.astype({'Rookie_year':'int','Final_year':'int'})
df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_Outs                int64
# Runs                    int64
# Highest_Inns_score      int64
# Ave                   float64
# Balls_Faced            object
# Battling_Stike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Players_name           object
# Players_country        object
# dtype: object

# %%
#split Ball_faced column
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced']
# Out:
# 0      9800
# 1      2667
# 2      1707
# 3       416
# 4      6558
#       ...
# 62     8662
# 63    15525
# 64     3118
# 65     3217
# 66     2110
# Name: Balls_Faced, Length: 63, dtype: object

# %%
df.isnull().sum()
# Out:
# Player                0
# Matches               0
# Inns                  0
# Not_Outs              0
# Runs                  0
# Highest_Inns_score    0
# Ave                   0
# Balls_Faced           3
# Battling_Stike        0
# 100                   0
# 50                    0
# 0                     0
# 4s                    0
# 6s                    0
# Rookie_year           0
# Final_year            0
# Players_name          0
# Players_country       0
# dtype: int64

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score  \
# 8         ED Weekes (WI)       48    81         5  4455                 207
# 17       CL Walcott (WI)       44    74         7  3798                 220
# 58  Hon.FS Jackson (ENG)       20    33         4  1415                 144
#
#       Ave Balls_Faced  Battling_Stike  100  50  0    4s  6s  Rookie_year  \
# 8   58.61         NaN             0.0   15  19  6  258+   2         1948
# 17  56.68         NaN             0.0   15  14  1  107+  11         1948
# 58  48.79         NaN             0.0    5   6  3   51+   0         1893
#
#     Final_year     Players_name Players_country
# 8         1958       ED Weekes               WI
# 17        1960      CL Walcott               WI
# 58        1905  Hon.FS Jackson              ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_score, Ave, Balls_Faced, Battling_Stike, 100, 50, 0, 4s, 6s, Rookie_year, Final_year, Players_name, Players_country]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score  \
# 0    DG Bradman (AUS)       52    80        10  6996                 334
# 1      AC Voges (AUS)       20    31         7  1485                 269
# 2     RG Pollock (SA)       23    41         4  2256                 274
# 3     GA Headley (WI)       22    40         4  2190                 270
# 4   H Sutcliffe (ENG)       54    84         9  4555                 194
# ..                ...      ...   ...       ...   ...                 ...
# 62   KD Walters (AUS)       74   125        14  5357                 250
# 63  GC Smith (ICC/SA)      117   205        13  9265                 277
# 64  WH Ponsford (AUS)       29    48         4  2122                 266
# 65    SJ McCabe (AUS)       39    62         5  2748                 232
# 66   DR Jardine (ENG)       22    33         6  1296                 127
#
#       Ave  Balls_Faced  Battling_Stike  100  50   0    4s  6s  Rookie_year  \
# ...

# %%
df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_Outs                int64
# Runs                    int64
# Highest_Inns_score      int64
# Ave                   float64
# Balls_Faced             int64
# Battling_Stike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_year             int64
# Final_year              int64
# Players_name           object
# Players_country        object
# dtype: object

# %%
#Calculate career length
df['career_length'] = df['Final_year'] - df['Rookie_year']
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score  \
# 0    DG Bradman (AUS)       52    80        10  6996                 334
# 1      AC Voges (AUS)       20    31         7  1485                 269
# 2     RG Pollock (SA)       23    41         4  2256                 274
# 3     GA Headley (WI)       22    40         4  2190                 270
# 4   H Sutcliffe (ENG)       54    84         9  4555                 194
# ..                ...      ...   ...       ...   ...                 ...
# 62   KD Walters (AUS)       74   125        14  5357                 250
# 63  GC Smith (ICC/SA)      117   205        13  9265                 277
# 64  WH Ponsford (AUS)       29    48         4  2122                 266
# 65    SJ McCabe (AUS)       39    62         5  2748                 232
# 66   DR Jardine (ENG)       22    33         6  1296                 127
#
#       Ave  Balls_Faced  Battling_Stike  100  50   0    4s  6s  Rookie_year  \
# ...

# %%
#Average career length for the player

# %%
df['career_length'].mean()
# Out:
# 12.968253968253968

# %%
#Average battling strike rate for player who played over 10 years
df['career-over-10years'] = df[df['career_length'] > 10]['Battling_Stike']
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_score  \
# 0    DG Bradman (AUS)       52    80        10  6996                 334
# 1      AC Voges (AUS)       20    31         7  1485                 269
# 2     RG Pollock (SA)       23    41         4  2256                 274
# 3     GA Headley (WI)       22    40         4  2190                 270
# 4   H Sutcliffe (ENG)       54    84         9  4555                 194
# ..                ...      ...   ...       ...   ...                 ...
# 62   KD Walters (AUS)       74   125        14  5357                 250
# 63  GC Smith (ICC/SA)      117   205        13  9265                 277
# 64  WH Ponsford (AUS)       29    48         4  2122                 266
# 65    SJ McCabe (AUS)       39    62         5  2748                 232
# 66   DR Jardine (ENG)       22    33         6  1296                 127
#
#       Ave  Balls_Faced  Battling_Stike  100  50   0    4s  6s  Rookie_year  \
# ...

# %%
df[df['career_length'] > 10]['Battling_Stike'].mean()
# Out:
# 47.966818181818184

# %%
#find number of players who played before 1960
df[df['Rookie_year']< 1960] ['Players_name'].count()
# Out:
# 23

# %%
#max highest inn score by country
df.groupby('Players_country')['Highest_Inns_score'].max()
# Out:
# Players_country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_score, dtype: int64
